# %%
## This notebook generates a youtube class labels files; This file can be used when parsing the Youtube WAV files to tfrecords

# %%
## Import packages
import os
import csv
import random
import math
import ntpath
import numpy as np
import pandas as pd
import time
from pathlib import Path
from scipy.io import wavfile

import tensorflow as tf
from tensorflow import gfile
from tensorflow import logging

# %%
import sys

# %%
# Set your serval data folder (should be correctly set already)
serval_data_folder = "../data"

# %%
# Set directories of WAV files
youtube_wav_samples_directory = serval_data_folder + "/wav_samples_youtube"

youtube_class_labels_filepath = serval_data_folder + "/csv_files/class_labels_indices.csv"

youtube_wav_balanced_train_class_labels_filepath   = youtube_wav_samples_directory + "/balanced_train_segments.csv"
youtube_wav_balanced_eval_class_labels_filepath    = youtube_wav_samples_directory + "/eval_segments.csv"
youtube_wav_unbalanced_train_class_labels_filepath = youtube_wav_samples_directory + "/unbalanced_train_segments.csv"

youtube_wav_balanced_train_sample_directory   = youtube_wav_samples_directory + "/bal"
youtube_wav_balanced_eval_sample_directory    = youtube_wav_samples_directory + "/eval"
youtube_wav_unbalanced_train_sample_directory = youtube_wav_samples_directory + "/unbal"

# %%
# Set output csv files
target_balanced_wav_samples_enumerated_filepath   = serval_data_folder + "/csv_files/wav_samples_youtube_balanced_all_enumerated_and_labeled.csv"
target_unbalanced_wav_samples_enumerated_filepath = serval_data_folder + "/csv_files/wav_samples_youtube_unbalanced_all_enumerated_and_labeled.csv"
target_eval_wav_samples_enumerated_filepath       = serval_data_folder + "/csv_files/wav_samples_youtube_eval_all_enumerated_and_labeled.csv"

# %%
def collectAndLabelYoutubeSamples(df_youtube_class_labels, wav_class_labels_filepath, wav_sample_directory, source):
    df_wav_class_labels = pd.read_csv(wav_class_labels_filepath, sep=",")    
    df_output_wav_files_classified = pd.DataFrame(columns=df_youtube_class_labels.columns.values.tolist() + ['source', 'filename', 'filepath'])
    
    start_time = time.time()
    files = gfile.Glob(str(wav_sample_directory + "/" + "*.wav"))
    count = 1
    for file in files:
        filename = ntpath.basename(file)[3:-4]
        df_labels = df_wav_class_labels.loc[df_wav_class_labels.filename.isin([filename])]
        
        if len(df_labels) != 1:
            print('[ERROR]: Found sample with ', len(df_labels) ,' class labels records (expected=1); filename=', filename, '; path=', file, sep='')
            continue
        
        classes = str(df_labels.youtube_mid_labels.iloc[0]).split(";")
        for class_ in classes:
            df_row = df_youtube_class_labels.loc[df_youtube_class_labels.mid == class_].copy(deep=True)
            
            if len(df_row) != 1:
                print('[ERROR]: Found sample with ', len(df_row) ,' youtube class labels records (expected=1); filename=', filename, '; youtube_mid_id=', class_, sep='')
                continue
            
            df_row['source'] = source
            df_row['filename'] = filename
            df_row['filepath'] = file
            df_output_wav_files_classified = df_output_wav_files_classified.append(df_row, ignore_index = True)
            
        count = count + 1
        if count % 100 == 0:
            print("[INFO]: Count=", count, "/", len(files), "; Time=", round((time.time() - start_time)), "; labels=", len(df_output_wav_files_classified),  sep='')
            
    
    df_output_wav_files_classified = df_output_wav_files_classified.rename(columns={'index': 'label'})
    return(df_output_wav_files_classified)

# %%
['index', 'label', 'description', 'file_path', 'filename', 'class_name']
# Out:
# ['index', 'label', 'description', 'file_path', 'filename', 'class_name']

# %%
# Load generic youtube class labels
df_youtube_class_labels = pd.read_csv(youtube_class_labels_filepath, sep=",")
df_youtube_class_labels.head()
# Out:
#    index        mid                   display_name
# 0      0   /m/09x0r                         Speech
# 1      1  /m/05zppz      Male speech, man speaking
# 2      2   /m/02zsn  Female speech, woman speaking
# 3      3   /m/0ytgt     Child speech, kid speaking
# 4      4  /m/01h8n0                   Conversation

# %%
#  collect and label balanced train samples
df_tmp = collectAndLabelYoutubeSamples(df_youtube_class_labels, 
                                       youtube_wav_balanced_train_class_labels_filepath,
                                       youtube_wav_balanced_train_sample_directory,
                                      'wav_samples_youtube/bal')
df_tmp.to_csv(target_balanced_wav_samples_enumerated_filepath, sep=';')

print(len(df_tmp))
print(df_tmp.head())
# Out:
# [INFO]: Count=100/1057; Time=1; labels=258
# [INFO]: Count=200/1057; Time=1; labels=494
# [INFO]: Count=300/1057; Time=2; labels=788
# [INFO]: Count=400/1057; Time=2; labels=1082
# [INFO]: Count=500/1057; Time=3; labels=1386
# [INFO]: Count=600/1057; Time=3; labels=1660
# [INFO]: Count=700/1057; Time=4; labels=1947
# [INFO]: Count=800/1057; Time=5; labels=2223
# [INFO]: Count=900/1057; Time=5; labels=2509
# [INFO]: Count=1000/1057; Time=6; labels=2784
# 2936
#   label         mid      display_name                   source     filename  \
# 0   427   /m/032s66  Gunshot, gunfire  wav_samples_youtube/bal  --aaILOrkII
# 1   431   /m/073cg4           Cap gun  wav_samples_youtube/bal  --aaILOrkII
# 2    32  /t/dd00003      Male singing  wav_samples_youtube/bal  --aO5cdqSAg
# 3    34  /t/dd00005     Child singing  wav_samples_youtube/bal  --aO5cdqSAg
# 4   137    /m/04rlf             Music  wav_samples_youtube/bal  -24dqQM_rDk
#
#                                             filepath
# 0  ..\data\wav_samples_youtube\bal\vid--aaILOrkII...
# 1  ..\data\wav_samples_youtube\bal\vid--aaILOrkII...
# 2  ..\data\wav_samples_youtube\bal\vid--aO5cdqSAg...
# 3  ..\data\wav_samples_youtube\bal\vid--aO5cdqSAg...
# 4  ..\data\wav_samples_youtube\bal\vid-24dqQM_rDk...

# %%
#  collect and label unbalanced train samples
df_tmp = collectAndLabelYoutubeSamples(df_youtube_class_labels, 
                                       youtube_wav_unbalanced_train_class_labels_filepath,
                                       youtube_wav_unbalanced_train_sample_directory,
                                      'wav_samples_youtube/unbal')
df_tmp.to_csv(target_unbalanced_wav_samples_enumerated_filepath, sep=';')

print(len(df_tmp))
print(df_tmp.head())
# Out:
# [INFO]: Count=100/50734; Time=5; labels=258
# [INFO]: Count=200/50734; Time=8; labels=517
# [INFO]: Count=300/50734; Time=11; labels=773
# [INFO]: Count=400/50734; Time=14; labels=1030
# [INFO]: Count=500/50734; Time=18; labels=1300
# [INFO]: Count=600/50734; Time=21; labels=1556
# [INFO]: Count=700/50734; Time=24; labels=1814
# [INFO]: Count=800/50734; Time=28; labels=2064
# [INFO]: Count=900/50734; Time=31; labels=2322
# [INFO]: Count=1000/50734; Time=34; labels=2569
# [INFO]: Count=1100/50734; Time=37; labels=2834
# [INFO]: Count=1200/50734; Time=41; labels=3092
# [INFO]: Count=1300/50734; Time=44; labels=3371
# [INFO]: Count=1400/50734; Time=47; labels=3634
# [INFO]: Count=1500/50734; Time=51; labels=3876
# [INFO]: Count=1600/50734; Time=54; labels=4126
# [INFO]: Count=1700/50734; Time=57; labels=4397
# [INFO]: Count=1800/50734; Time=61; labels=4654
# [INFO]: Count=1900/50734; Time=64; labels=4907
# [INFO]: Count=2000/50734; Time=67; labels=5165
# [INFO]: Count=2100/50734; Time=71; labels=5412
# [INFO]: Count=2200/50734; Time=74; labels=5666
# [INFO]: Count=2300/50734; Time=77; labels=5923
# [INFO]: Count=2400/50734; Time=81; labels=6191
# [INFO]: Count=2500/50734; Time=84; labels=6458
# [INFO]: Count=2600/50734; Time=87; labels=6722
# [INFO]: Count=2700/50734; Time=91; labels=6983
# [INFO]: Count=2800/50734; Time=94; labels=7259
# [INFO]: Count=2900/50734; Time=97; labels=7524
# [INFO]: Count=3000/50734; Time=101; labels=7769
# [INFO]: Count=3100/50734; Time=104; labels=8030
# [INFO]: Count=3200/50734; Time=107; labels=8302
# [INFO]: Count=3300/50734; Time=111; labels=8586
# [INFO]: Count=3400/50734; Time=114; labels=8873
# [INFO]: Count=3500/50734; Time=118; labels=9136
# [INFO]: Count=3600/50734; Time=121; labels=9388
# [INFO]: Count=3700/50734; Time=124; labels=9647
# [INFO]: Count=3800/50734; Time=128; labels=9899
# [INFO]: Count=3900/50734; Time=131; labels=10162
# [INFO]: Count=4000/50734; Time=134; labels=10429
# [INFO]: Count=4100/50734; Time=138; labels=10704
# [INFO]: Count=4200/50734; Time=141; labels=10966
# [INFO]: Count=4300/50734; Time=145; labels=11228
# [INFO]: Count=4400/50734; Time=148; labels=11475
# [INFO]: Count=4500/50734; Time=151; labels=11748
# [INFO]: Count=4600/50734; Time=155; labels=12001
# [INFO]: Count=4700/50734; Time=158; labels=12264
# [INFO]: Count=4800/50734; Time=161; labels=12521
# [INFO]: Count=4900/50734; Time=165; labels=12795
# [INFO]: Count=5000/50734; Time=168; labels=13067
# [INFO]: Count=5100/50734; Time=172; labels=13334
# [INFO]: Count=5200/50734; Time=175; labels=13604
# [INFO]: Count=5300/50734; Time=179; labels=13858
# [INFO]: Count=5400/50734; Time=182; labels=14114
# [INFO]: Count=5500/50734; Time=185; labels=14376
# [INFO]: Count=5600/50734; Time=189; labels=14619
# [INFO]: Count=5700/50734; Time=192; labels=14886
# [INFO]: Count=5800/50734; Time=196; labels=15165
# [INFO]: Count=5900/50734; Time=199; labels=15428
# [INFO]: Count=6000/50734; Time=203; labels=15691
# [INFO]: Count=6100/50734; Time=206; labels=15950
# [INFO]: Count=6200/50734; Time=210; labels=16212
# [INFO]: Count=6300/50734; Time=213; labels=16455
# [INFO]: Count=6400/50734; Time=217; labels=16716
# [INFO]: Count=6500/50734; Time=220; labels=16966
# [INFO]: Count=6600/50734; Time=224; labels=17240
# [INFO]: Count=6700/50734; Time=227; labels=17499
# [INFO]: Count=6800/50734; Time=231; labels=17757
# [INFO]: Count=6900/50734; Time=234; labels=18013
# [INFO]: Count=7000/50734; Time=238; labels=18275
# [INFO]: Count=7100/50734; Time=241; labels=18541
# [INFO]: Count=7200/50734; Time=245; labels=18790
# [INFO]: Count=7300/50734; Time=248; labels=19042
# [INFO]: Count=7400/50734; Time=252; labels=19308
# [INFO]: Count=7500/50734; Time=255; labels=19572
# [INFO]: Count=7600/50734; Time=259; labels=19834
# [INFO]: Count=7700/50734; Time=262; labels=20072
# [INFO]: Count=7800/50734; Time=265; labels=20327
# [INFO]: Count=7900/50734; Time=269; labels=20611
# [INFO]: Count=8000/50734; Time=272; labels=20865
# [INFO]: Count=8100/50734; Time=276; labels=21134
# [INFO]: Count=8200/50734; Time=280; labels=21396
# [INFO]: Count=8300/50734; Time=283; labels=21664
# [INFO]: Count=8400/50734; Time=287; labels=21908
# [INFO]: Count=8500/50734; Time=290; labels=22170
# [INFO]: Count=8600/50734; Time=294; labels=22426
# [INFO]: Count=8700/50734; Time=298; labels=22678
# [INFO]: Count=8800/50734; Time=301; labels=22945
# [INFO]: Count=8900/50734; Time=305; labels=23208
# [INFO]: Count=9000/50734; Time=309; labels=23454
# [INFO]: Count=9100/50734; Time=312; labels=23721
# [INFO]: Count=9200/50734; Time=316; labels=23996
# [INFO]: Count=9300/50734; Time=320; labels=24260
# [INFO]: Count=9400/50734; Time=323; labels=24519
# [INFO]: Count=9500/50734; Time=327; labels=24781
# [INFO]: Count=9600/50734; Time=331; labels=25030
# [INFO]: Count=9700/50734; Time=334; labels=25286
# [INFO]: Count=9800/50734; Time=338; labels=25551
# [INFO]: Count=9900/50734; Time=342; labels=25789
# [INFO]: Count=10000/50734; Time=345; labels=26037
# [INFO]: Count=10100/50734; Time=349; labels=26300
# [INFO]: Count=10200/50734; Time=353; labels=26563
# [INFO]: Count=10300/50734; Time=357; labels=26830
# [INFO]: Count=10400/50734; Time=361; labels=27094
# [INFO]: Count=10500/50734; Time=364; labels=27365
# [INFO]: Count=10600/50734; Time=368; labels=27614
# [INFO]: Count=10700/50734; Time=372; labels=27863
# [INFO]: Count=10800/50734; Time=376; labels=28119
# [INFO]: Count=10900/50734; Time=380; labels=28390
# [INFO]: Count=11000/50734; Time=383; labels=28625
# [INFO]: Count=11100/50734; Time=387; labels=28884
# [INFO]: Count=11200/50734; Time=391; labels=29131
# [INFO]: Count=11300/50734; Time=395; labels=29384
# [INFO]: Count=11400/50734; Time=399; labels=29636
# [INFO]: Count=11500/50734; Time=402; labels=29867
# [INFO]: Count=11600/50734; Time=406; labels=30099
# [INFO]: Count=11700/50734; Time=410; labels=30354
# [INFO]: Count=11800/50734; Time=414; labels=30608
# [INFO]: Count=11900/50734; Time=418; labels=30861
# [INFO]: Count=12000/50734; Time=422; labels=31120
# [INFO]: Count=12100/50734; Time=425; labels=31365
# [INFO]: Count=12200/50734; Time=429; labels=31608
# [INFO]: Count=12300/50734; Time=433; labels=31859
# [INFO]: Count=12400/50734; Time=437; labels=32109
# [INFO]: Count=12500/50734; Time=441; labels=32376
# [INFO]: Count=12600/50734; Time=445; labels=32647
# [INFO]: Count=12700/50734; Time=449; labels=32900
# [INFO]: Count=12800/50734; Time=452; labels=33149
# [INFO]: Count=12900/50734; Time=456; labels=33391
# [INFO]: Count=13000/50734; Time=460; labels=33628
# [INFO]: Count=13100/50734; Time=464; labels=33861
# [INFO]: Count=13200/50734; Time=468; labels=34112
# [INFO]: Count=13300/50734; Time=471; labels=34348
# [INFO]: Count=13400/50734; Time=475; labels=34591
# [INFO]: Count=13500/50734; Time=479; labels=34831
# [INFO]: Count=13600/50734; Time=483; labels=35096
# [INFO]: Count=13700/50734; Time=487; labels=35349
# [INFO]: Count=13800/50734; Time=491; labels=35598
# [INFO]: Count=13900/50734; Time=495; labels=35851
# [INFO]: Count=14000/50734; Time=499; labels=36109
# [INFO]: Count=14100/50734; Time=503; labels=36354
# [INFO]: Count=14200/50734; Time=507; labels=36612
# [INFO]: Count=14300/50734; Time=511; labels=36864
# [INFO]: Count=14400/50734; Time=515; labels=37118
# [INFO]: Count=14500/50734; Time=518; labels=37347
# [INFO]: Count=14600/50734; Time=522; labels=37609
# [INFO]: Count=14700/50734; Time=526; labels=37878
# [INFO]: Count=14800/50734; Time=530; labels=38141
# [INFO]: Count=14900/50734; Time=534; labels=38388
# [INFO]: Count=15000/50734; Time=538; labels=38645
# [INFO]: Count=15100/50734; Time=543; labels=38897
# [INFO]: Count=15200/50734; Time=547; labels=39162
# [INFO]: Count=15300/50734; Time=551; labels=39425
# [INFO]: Count=15400/50734; Time=555; labels=39678
# [INFO]: Count=15500/50734; Time=559; labels=39937
# [INFO]: Count=15600/50734; Time=563; labels=40198
# [INFO]: Count=15700/50734; Time=567; labels=40464
# [INFO]: Count=15800/50734; Time=571; labels=40708
# [INFO]: Count=15900/50734; Time=575; labels=40960
# [INFO]: Count=16000/50734; Time=579; labels=41199
# [INFO]: Count=16100/50734; Time=583; labels=41444
# [INFO]: Count=16200/50734; Time=587; labels=41691
# [INFO]: Count=16300/50734; Time=591; labels=41951
# [INFO]: Count=16400/50734; Time=595; labels=42215
# [INFO]: Count=16500/50734; Time=599; labels=42458
# [INFO]: Count=16600/50734; Time=603; labels=42715
# [INFO]: Count=16700/50734; Time=607; labels=42955
# [INFO]: Count=16800/50734; Time=611; labels=43210
# [INFO]: Count=16900/50734; Time=615; labels=43459
# [INFO]: Count=17000/50734; Time=619; labels=43706
# [INFO]: Count=17100/50734; Time=623; labels=43943
# [INFO]: Count=17200/50734; Time=627; labels=44205
# [INFO]: Count=17300/50734; Time=632; labels=44473
# [INFO]: Count=17400/50734; Time=636; labels=44745
# [INFO]: Count=17500/50734; Time=640; labels=45005
# [INFO]: Count=17600/50734; Time=644; labels=45241
# [INFO]: Count=17700/50734; Time=648; labels=45515
# [INFO]: Count=17800/50734; Time=653; labels=45782
# [INFO]: Count=17900/50734; Time=657; labels=46036
# [INFO]: Count=18000/50734; Time=661; labels=46262
# [INFO]: Count=18100/50734; Time=665; labels=46502
# [INFO]: Count=18200/50734; Time=669; labels=46759
# [INFO]: Count=18300/50734; Time=673; labels=47023
# [INFO]: Count=18400/50734; Time=677; labels=47281
# [INFO]: Count=18500/50734; Time=682; labels=47544
# [INFO]: Count=18600/50734; Time=686; labels=47801
# [INFO]: Count=18700/50734; Time=690; labels=48079
# [INFO]: Count=18800/50734; Time=694; labels=48324
# [INFO]: Count=18900/50734; Time=699; labels=48602
# [INFO]: Count=19000/50734; Time=703; labels=48862
# [INFO]: Count=19100/50734; Time=707; labels=49131
# [INFO]: Count=19200/50734; Time=712; labels=49400
# [INFO]: Count=19300/50734; Time=716; labels=49658
# [INFO]: Count=19400/50734; Time=720; labels=49925
# [INFO]: Count=19500/50734; Time=724; labels=50194
# [INFO]: Count=19600/50734; Time=729; labels=50455
# [INFO]: Count=19700/50734; Time=733; labels=50721
# [INFO]: Count=19800/50734; Time=737; labels=50979
# [INFO]: Count=19900/50734; Time=742; labels=51232
# [INFO]: Count=20000/50734; Time=746; labels=51505
# [INFO]: Count=20100/50734; Time=750; labels=51760
# [INFO]: Count=20200/50734; Time=755; labels=52017
# [INFO]: Count=20300/50734; Time=759; labels=52279
# [INFO]: Count=20400/50734; Time=763; labels=52546
# [INFO]: Count=20500/50734; Time=768; labels=52807
# [INFO]: Count=20600/50734; Time=772; labels=53058
# [INFO]: Count=20700/50734; Time=776; labels=53309
# [INFO]: Count=20800/50734; Time=781; labels=53566
# [INFO]: Count=20900/50734; Time=785; labels=53822
# [INFO]: Count=21000/50734; Time=789; labels=54079
# [INFO]: Count=21100/50734; Time=794; labels=54360
# [INFO]: Count=21200/50734; Time=798; labels=54632
# [INFO]: Count=21300/50734; Time=803; labels=54905
# [INFO]: Count=21400/50734; Time=807; labels=55159
# [INFO]: Count=21500/50734; Time=812; labels=55417
# [INFO]: Count=21600/50734; Time=816; labels=55678
# [INFO]: Count=21700/50734; Time=821; labels=55954
# [INFO]: Count=21800/50734; Time=825; labels=56213
# [INFO]: Count=21900/50734; Time=830; labels=56486
# [INFO]: Count=22000/50734; Time=834; labels=56762
# [INFO]: Count=22100/50734; Time=839; labels=57024
# [INFO]: Count=22200/50734; Time=843; labels=57298
# [INFO]: Count=22300/50734; Time=848; labels=57575
# [INFO]: Count=22400/50734; Time=852; labels=57862
# [INFO]: Count=22500/50734; Time=857; labels=58129
# [INFO]: Count=22600/50734; Time=861; labels=58388
# [INFO]: Count=22700/50734; Time=866; labels=58656
# [INFO]: Count=22800/50734; Time=870; labels=58924
# [INFO]: Count=22900/50734; Time=875; labels=59213
# [INFO]: Count=23000/50734; Time=880; labels=59491
# [INFO]: Count=23100/50734; Time=884; labels=59757
# [INFO]: Count=23200/50734; Time=889; labels=60015
# [INFO]: Count=23300/50734; Time=893; labels=60279
# [INFO]: Count=23400/50734; Time=898; labels=60535
# [INFO]: Count=23500/50734; Time=902; labels=60791
# [INFO]: Count=23600/50734; Time=907; labels=61084
# [INFO]: Count=23700/50734; Time=912; labels=61347
# [INFO]: Count=23800/50734; Time=916; labels=61615
# [INFO]: Count=23900/50734; Time=921; labels=61874
# [INFO]: Count=24000/50734; Time=926; labels=62143
# [INFO]: Count=24100/50734; Time=930; labels=62397
# [INFO]: Count=24200/50734; Time=935; labels=62673
# [INFO]: Count=24300/50734; Time=940; labels=62942
# [INFO]: Count=24400/50734; Time=945; labels=63210
# [INFO]: Count=24500/50734; Time=949; labels=63486
# [INFO]: Count=24600/50734; Time=954; labels=63772
# [INFO]: Count=24700/50734; Time=959; labels=64025
# [INFO]: Count=24800/50734; Time=963; labels=64286
# [INFO]: Count=24900/50734; Time=968; labels=64555
# [INFO]: Count=25000/50734; Time=973; labels=64823
# [INFO]: Count=25100/50734; Time=978; labels=65108
# [INFO]: Count=25200/50734; Time=982; labels=65375
# [INFO]: Count=25300/50734; Time=987; labels=65626
# [INFO]: Count=25400/50734; Time=992; labels=65888
# [INFO]: Count=25500/50734; Time=997; labels=66164
# [INFO]: Count=25600/50734; Time=1001; labels=66417
# [INFO]: Count=25700/50734; Time=1006; labels=66694
# [INFO]: Count=25800/50734; Time=1011; labels=66968
# [INFO]: Count=25900/50734; Time=1016; labels=67218
# [INFO]: Count=26000/50734; Time=1020; labels=67484
# [INFO]: Count=26100/50734; Time=1025; labels=67742
# [INFO]: Count=26200/50734; Time=1030; labels=68011
# [INFO]: Count=26300/50734; Time=1035; labels=68276
# [INFO]: Count=26400/50734; Time=1040; labels=68545
# [INFO]: Count=26500/50734; Time=1045; labels=68813
# [INFO]: Count=26600/50734; Time=1050; labels=69097
# [INFO]: Count=26700/50734; Time=1055; labels=69365
# [INFO]: Count=26800/50734; Time=1059; labels=69618
# [INFO]: Count=26900/50734; Time=1064; labels=69885
# [INFO]: Count=27000/50734; Time=1069; labels=70151
# [INFO]: Count=27100/50734; Time=1074; labels=70423
# [INFO]: Count=27200/50734; Time=1079; labels=70686
# [INFO]: Count=27300/50734; Time=1084; labels=70958
# [INFO]: Count=27400/50734; Time=1089; labels=71206
# [INFO]: Count=27500/50734; Time=1094; labels=71495
# [INFO]: Count=27600/50734; Time=1099; labels=71774
# [INFO]: Count=27700/50734; Time=1104; labels=72049
# [INFO]: Count=27800/50734; Time=1109; labels=72302
# [INFO]: Count=27900/50734; Time=1114; labels=72572
# [INFO]: Count=28000/50734; Time=1119; labels=72840
# [INFO]: Count=28100/50734; Time=1124; labels=73102
# [INFO]: Count=28200/50734; Time=1129; labels=73356
# [INFO]: Count=28300/50734; Time=1133; labels=73597
# [INFO]: Count=28400/50734; Time=1138; labels=73871
# [INFO]: Count=28500/50734; Time=1144; labels=74160
# [INFO]: Count=28600/50734; Time=1149; labels=74446
# [INFO]: Count=28700/50734; Time=1154; labels=74706
# [INFO]: Count=28800/50734; Time=1159; labels=74980
# [INFO]: Count=28900/50734; Time=1164; labels=75244
# [INFO]: Count=29000/50734; Time=1169; labels=75517
# [INFO]: Count=29100/50734; Time=1174; labels=75770
# [INFO]: Count=29200/50734; Time=1179; labels=76058
# [INFO]: Count=29300/50734; Time=1184; labels=76332
# [INFO]: Count=29400/50734; Time=1190; labels=76607
# [INFO]: Count=29500/50734; Time=1195; labels=76878
# [INFO]: Count=29600/50734; Time=1200; labels=77136
# [INFO]: Count=29700/50734; Time=1205; labels=77405
# [INFO]: Count=29800/50734; Time=1210; labels=77663
# [INFO]: Count=29900/50734; Time=1215; labels=77918
# [INFO]: Count=30000/50734; Time=1220; labels=78185
# [INFO]: Count=30100/50734; Time=1225; labels=78458
# [INFO]: Count=30200/50734; Time=1230; labels=78712
# [INFO]: Count=30300/50734; Time=1235; labels=78960
# [INFO]: Count=30400/50734; Time=1241; labels=79224
# [INFO]: Count=30500/50734; Time=1246; labels=79489
# [INFO]: Count=30600/50734; Time=1251; labels=79745
# [INFO]: Count=30700/50734; Time=1256; labels=79989
# [INFO]: Count=30800/50734; Time=1261; labels=80252
# [INFO]: Count=30900/50734; Time=1266; labels=80521
# [INFO]: Count=31000/50734; Time=1271; labels=80777
# [INFO]: Count=31100/50734; Time=1277; labels=81037
# [INFO]: Count=31200/50734; Time=1282; labels=81284
# [INFO]: Count=31300/50734; Time=1287; labels=81568
# [INFO]: Count=31400/50734; Time=1292; labels=81823
# [INFO]: Count=31500/50734; Time=1298; labels=82092
# [INFO]: Count=31600/50734; Time=1303; labels=82343
# [INFO]: Count=31700/50734; Time=1308; labels=82598
# [INFO]: Count=31800/50734; Time=1313; labels=82854
# [INFO]: Count=31900/50734; Time=1318; labels=83125
# [INFO]: Count=32000/50734; Time=1324; labels=83378
# [INFO]: Count=32100/50734; Time=1329; labels=83646
# [INFO]: Count=32200/50734; Time=1334; labels=83903
# [INFO]: Count=32300/50734; Time=1340; labels=84202
# [INFO]: Count=32400/50734; Time=1345; labels=84489
# [INFO]: Count=32500/50734; Time=1351; labels=84741
# [INFO]: Count=32600/50734; Time=1356; labels=85008
# [INFO]: Count=32700/50734; Time=1362; labels=85278
# [INFO]: Count=32800/50734; Time=1367; labels=85531
# [INFO]: Count=32900/50734; Time=1372; labels=85800
# [INFO]: Count=33000/50734; Time=1378; labels=86068
# [INFO]: Count=33100/50734; Time=1383; labels=86333
# [INFO]: Count=33200/50734; Time=1389; labels=86597
# [INFO]: Count=33300/50734; Time=1395; labels=86897
# [INFO]: Count=33400/50734; Time=1400; labels=87173
# [INFO]: Count=33500/50734; Time=1406; labels=87434
# [INFO]: Count=33600/50734; Time=1411; labels=87687
# [INFO]: Count=33700/50734; Time=1416; labels=87936
# [INFO]: Count=33800/50734; Time=1422; labels=88197
# [INFO]: Count=33900/50734; Time=1427; labels=88463
# [INFO]: Count=34000/50734; Time=1433; labels=88728
# [INFO]: Count=34100/50734; Time=1438; labels=88975
# [INFO]: Count=34200/50734; Time=1444; labels=89231
# [INFO]: Count=34300/50734; Time=1450; labels=89500
# [INFO]: Count=34400/50734; Time=1455; labels=89789
# [INFO]: Count=34500/50734; Time=1461; labels=90037
# [INFO]: Count=34600/50734; Time=1467; labels=90309
# [INFO]: Count=34700/50734; Time=1472; labels=90561
# [INFO]: Count=34800/50734; Time=1477; labels=90803
# [INFO]: Count=34900/50734; Time=1483; labels=91072
# [INFO]: Count=35000/50734; Time=1489; labels=91333
# [INFO]: Count=35100/50734; Time=1494; labels=91600
# [INFO]: Count=35200/50734; Time=1500; labels=91858
# [INFO]: Count=35300/50734; Time=1505; labels=92120
# [INFO]: Count=35400/50734; Time=1511; labels=92386
# [INFO]: Count=35500/50734; Time=1517; labels=92634
# [INFO]: Count=35600/50734; Time=1522; labels=92879
# [INFO]: Count=35700/50734; Time=1528; labels=93136
# [INFO]: Count=35800/50734; Time=1533; labels=93396
# [INFO]: Count=35900/50734; Time=1539; labels=93648
# [INFO]: Count=36000/50734; Time=1545; labels=93894
# [INFO]: Count=36100/50734; Time=1550; labels=94168
# [INFO]: Count=36200/50734; Time=1556; labels=94423
# [INFO]: Count=36300/50734; Time=1562; labels=94680
# [INFO]: Count=36400/50734; Time=1567; labels=94922
# [INFO]: Count=36500/50734; Time=1573; labels=95188
# [INFO]: Count=36600/50734; Time=1579; labels=95480
# [INFO]: Count=36700/50734; Time=1585; labels=95745
# [INFO]: Count=36800/50734; Time=1591; labels=95997
# [INFO]: Count=36900/50734; Time=1596; labels=96257
# [INFO]: Count=37000/50734; Time=1602; labels=96520
# [INFO]: Count=37100/50734; Time=1608; labels=96798
# [INFO]: Count=37200/50734; Time=1614; labels=97083
# [INFO]: Count=37300/50734; Time=1620; labels=97333
# [INFO]: Count=37400/50734; Time=1626; labels=97602
# [INFO]: Count=37500/50734; Time=1632; labels=97848
# [INFO]: Count=37600/50734; Time=1638; labels=98111
# [INFO]: Count=37700/50734; Time=1643; labels=98370
# [INFO]: Count=37800/50734; Time=1649; labels=98637
# [INFO]: Count=37900/50734; Time=1655; labels=98882
# [INFO]: Count=38000/50734; Time=1661; labels=99173
# [INFO]: Count=38100/50734; Time=1667; labels=99417
# [INFO]: Count=38200/50734; Time=1673; labels=99672
# [INFO]: Count=38300/50734; Time=1679; labels=99922
# [INFO]: Count=38400/50734; Time=1685; labels=100220
# [INFO]: Count=38500/50734; Time=1691; labels=100493
# [INFO]: Count=38600/50734; Time=1697; labels=100753
# [INFO]: Count=38700/50734; Time=1703; labels=101001
# [INFO]: Count=38800/50734; Time=1709; labels=101262
# [INFO]: Count=38900/50734; Time=1715; labels=101533
# [INFO]: Count=39000/50734; Time=1721; labels=101805
# [INFO]: Count=39100/50734; Time=1727; labels=102070
# [INFO]: Count=39200/50734; Time=1733; labels=102344
# [INFO]: Count=39300/50734; Time=1740; labels=102613
# [INFO]: Count=39400/50734; Time=1746; labels=102879
# [INFO]: Count=39500/50734; Time=1752; labels=103160
# [INFO]: Count=39600/50734; Time=1758; labels=103416
# [INFO]: Count=39700/50734; Time=1764; labels=103685
# [INFO]: Count=39800/50734; Time=1771; labels=103968
# [INFO]: Count=39900/50734; Time=1777; labels=104221
# [INFO]: Count=40000/50734; Time=1783; labels=104469
# [INFO]: Count=40100/50734; Time=1789; labels=104743
# [INFO]: Count=40200/50734; Time=1795; labels=104997
# [INFO]: Count=40300/50734; Time=1801; labels=105266
# [INFO]: Count=40400/50734; Time=1808; labels=105515
# [INFO]: Count=40500/50734; Time=1814; labels=105794
# [INFO]: Count=40600/50734; Time=1820; labels=106033
# [INFO]: Count=40700/50734; Time=1826; labels=106306
# [INFO]: Count=40800/50734; Time=1833; labels=106558
# [INFO]: Count=40900/50734; Time=1839; labels=106810
# [INFO]: Count=41000/50734; Time=1845; labels=107078
# [INFO]: Count=41100/50734; Time=1851; labels=107359
# [INFO]: Count=41200/50734; Time=1858; labels=107618
# [INFO]: Count=41300/50734; Time=1864; labels=107887
# [INFO]: Count=41400/50734; Time=1870; labels=108141
# [INFO]: Count=41500/50734; Time=1876; labels=108391
# [INFO]: Count=41600/50734; Time=1883; labels=108676
# [INFO]: Count=41700/50734; Time=1889; labels=108934
# [INFO]: Count=41800/50734; Time=1896; labels=109213
# [INFO]: Count=41900/50734; Time=1902; labels=109464
# [INFO]: Count=42000/50734; Time=1909; labels=109747
# [INFO]: Count=42100/50734; Time=1915; labels=109994
# [INFO]: Count=42200/50734; Time=1922; labels=110271
# [INFO]: Count=42300/50734; Time=1928; labels=110545
# [INFO]: Count=42400/50734; Time=1935; labels=110781
# [INFO]: Count=42500/50734; Time=1941; labels=111033
# [INFO]: Count=42600/50734; Time=1948; labels=111305
# [INFO]: Count=42700/50734; Time=1954; labels=111562
# [INFO]: Count=42800/50734; Time=1960; labels=111817
# [INFO]: Count=42900/50734; Time=1967; labels=112074
# [INFO]: Count=43000/50734; Time=1974; labels=112354
# [INFO]: Count=43100/50734; Time=1980; labels=112631
# [INFO]: Count=43200/50734; Time=1987; labels=112891
# [INFO]: Count=43300/50734; Time=1994; labels=113163
# [INFO]: Count=43400/50734; Time=2001; labels=113437
# [INFO]: Count=43500/50734; Time=2007; labels=113698
# [INFO]: Count=43600/50734; Time=2014; labels=113954
# [INFO]: Count=43700/50734; Time=2020; labels=114224
# [INFO]: Count=43800/50734; Time=2027; labels=114478
# [INFO]: Count=43900/50734; Time=2034; labels=114755
# [INFO]: Count=44000/50734; Time=2041; labels=115030
# [INFO]: Count=44100/50734; Time=2047; labels=115300
# [INFO]: Count=44200/50734; Time=2054; labels=115556
# [INFO]: Count=44300/50734; Time=2060; labels=115791
# [INFO]: Count=44400/50734; Time=2068; labels=116094
# [INFO]: Count=44500/50734; Time=2074; labels=116342
# [INFO]: Count=44600/50734; Time=2080; labels=116590
# [INFO]: Count=44700/50734; Time=2087; labels=116856
# [INFO]: Count=44800/50734; Time=2094; labels=117108
# [INFO]: Count=44900/50734; Time=2101; labels=117367
# [INFO]: Count=45000/50734; Time=2107; labels=117619
# [INFO]: Count=45100/50734; Time=2114; labels=117848
# [INFO]: Count=45200/50734; Time=2121; labels=118117
# [INFO]: Count=45300/50734; Time=2128; labels=118386
# [INFO]: Count=45400/50734; Time=2134; labels=118651
# [INFO]: Count=45500/50734; Time=2141; labels=118920
# [INFO]: Count=45600/50734; Time=2148; labels=119177
# [INFO]: Count=45700/50734; Time=2155; labels=119433
# [INFO]: Count=45800/50734; Time=2162; labels=119707
# [INFO]: Count=45900/50734; Time=2168; labels=119944
# [INFO]: Count=46000/50734; Time=2175; labels=120209
# [INFO]: Count=46100/50734; Time=2182; labels=120475
# [INFO]: Count=46200/50734; Time=2188; labels=120719
# [INFO]: Count=46300/50734; Time=2195; labels=120978
# [INFO]: Count=46400/50734; Time=2202; labels=121239
# [INFO]: Count=46500/50734; Time=2209; labels=121471
# [INFO]: Count=46600/50734; Time=2215; labels=121717
# [INFO]: Count=46700/50734; Time=2222; labels=121969
# [INFO]: Count=46800/50734; Time=2229; labels=122217
# [INFO]: Count=46900/50734; Time=2236; labels=122479
# [INFO]: Count=47000/50734; Time=2243; labels=122742
# [INFO]: Count=47100/50734; Time=2249; labels=122989
# [INFO]: Count=47200/50734; Time=2256; labels=123248
# [INFO]: Count=47300/50734; Time=2263; labels=123514
# [INFO]: Count=47400/50734; Time=2270; labels=123771
# [INFO]: Count=47500/50734; Time=2277; labels=124042
# [INFO]: Count=47600/50734; Time=2284; labels=124301
# [INFO]: Count=47700/50734; Time=2292; labels=124580
# [INFO]: Count=47800/50734; Time=2298; labels=124834
# [INFO]: Count=47900/50734; Time=2305; labels=125091
# [INFO]: Count=48000/50734; Time=2313; labels=125374
# [INFO]: Count=48100/50734; Time=2319; labels=125626
# [INFO]: Count=48200/50734; Time=2327; labels=125888
# [INFO]: Count=48300/50734; Time=2334; labels=126155
# [INFO]: Count=48400/50734; Time=2341; labels=126431
# [INFO]: Count=48500/50734; Time=2348; labels=126697
# [INFO]: Count=48600/50734; Time=2355; labels=126979
# [INFO]: Count=48700/50734; Time=2363; labels=127246
# [INFO]: Count=48800/50734; Time=2370; labels=127529
# [INFO]: Count=48900/50734; Time=2377; labels=127767
# [INFO]: Count=49000/50734; Time=2384; labels=128010
# [INFO]: Count=49100/50734; Time=2391; labels=128271
# [INFO]: Count=49200/50734; Time=2399; labels=128535
# [INFO]: Count=49300/50734; Time=2406; labels=128823
# [INFO]: Count=49400/50734; Time=2414; labels=129073
# [INFO]: Count=49500/50734; Time=2421; labels=129332
# [INFO]: Count=49600/50734; Time=2428; labels=129599
# [INFO]: Count=49700/50734; Time=2435; labels=129853
# [INFO]: Count=49800/50734; Time=2443; labels=130112
# [INFO]: Count=49900/50734; Time=2451; labels=130408
# [INFO]: Count=50000/50734; Time=2459; labels=130677
# [INFO]: Count=50100/50734; Time=2467; labels=130952
# [INFO]: Count=50200/50734; Time=2474; labels=131215
# [INFO]: Count=50300/50734; Time=2482; labels=131474
# [INFO]: Count=50400/50734; Time=2489; labels=131753
# [INFO]: Count=50500/50734; Time=2497; labels=132049
# [INFO]: Count=50600/50734; Time=2505; labels=132298
# [INFO]: Count=50700/50734; Time=2512; labels=132565
# 132660
#   label         mid          display_name                     source  \
# 0   306   /m/012f08  Motor vehicle (road)  wav_samples_youtube/unbal
# 1   300    /m/07yv9               Vehicle  wav_samples_youtube/unbal
# 2   307     /m/0k4j                   Car  wav_samples_youtube/unbal
# 3   314  /t/dd00134        Car passing by  wav_samples_youtube/unbal
# 4   316    /m/07r04                 Truck  wav_samples_youtube/unbal
#
#       filename                                           filepath
# 0  ---lTs1dxhU  ..\data\wav_samples_youtube\unbal\wav\vid---lT...
# 1  ---lTs1dxhU  ..\data\wav_samples_youtube\unbal\wav\vid---lT...
# 2  ---lTs1dxhU  ..\data\wav_samples_youtube\unbal\wav\vid---lT...
# 3  ---lTs1dxhU  ..\data\wav_samples_youtube\unbal\wav\vid---lT...
# 4  --12UOziMF0  ..\data\wav_samples_youtube\unbal\wav\vid--12U...

# %%
#  collect and label balanced eval samples
df_tmp = collectAndLabelYoutubeSamples(df_youtube_class_labels, 
                                       youtube_wav_balanced_eval_class_labels_filepath,
                                       youtube_wav_balanced_eval_sample_directory,
                                      'wav_samples_youtube/eval')
df_tmp.to_csv(target_eval_wav_samples_enumerated_filepath, sep=';')

print(len(df_tmp))
print(df_tmp.head())
# Out:
# [INFO]: Count=100/1072; Time=1; labels=252
# [INFO]: Count=200/1072; Time=1; labels=540
# [INFO]: Count=300/1072; Time=2; labels=829
# [INFO]: Count=400/1072; Time=2; labels=1114
# [INFO]: Count=500/1072; Time=3; labels=1419
# [INFO]: Count=600/1072; Time=4; labels=1726
# [INFO]: Count=700/1072; Time=4; labels=2038
# [INFO]: Count=800/1072; Time=5; labels=2333
# [INFO]: Count=900/1072; Time=5; labels=2584
# [INFO]: Count=1000/1072; Time=6; labels=2877
# 3100
#   label        mid display_name                    source     filename  \
# 0   137   /m/04rlf        Music  wav_samples_youtube/eval  -1II0Di9Hkc
# 1   525   /m/06bz3        Radio  wav_samples_youtube/eval  -1II0Di9Hkc
# 2   137   /m/04rlf        Music  wav_samples_youtube/eval  -1OlgJWehn8
# 3   525   /m/06bz3        Radio  wav_samples_youtube/eval  -1OlgJWehn8
# 4   347  /m/01j4z9     Chainsaw  wav_samples_youtube/eval  -23CeprtibU
#
#                                             filepath
# 0  ..\data\wav_samples_youtube\eval\vid-1II0Di9Hk...
# 1  ..\data\wav_samples_youtube\eval\vid-1II0Di9Hk...
# 2  ..\data\wav_samples_youtube\eval\vid-1OlgJWehn...
# 3  ..\data\wav_samples_youtube\eval\vid-1OlgJWehn...
# 4  ..\data\wav_samples_youtube\eval\vid-23Ceprtib...
