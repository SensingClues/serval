# %% [markdown]
# ## Serval Train Model
#
# We will setup a deep neural network with keras.
#
# We presume this notebook is run with a GPU available.

# %%
import json
import logging
import os
import time
import warnings

import librosa
import numpy as np
import pandas as pd
import pydub
import sklearn.preprocessing
from tqdm import tqdm

THEANO_FLAGS = ('device=gpu0,'
                'floatX=float32,'
                'dnn.conv.algo_bwd_filter=deterministic,'
                'dnn.conv.algo_bwd_data=deterministic')

os.environ['THEANO_FLAGS'] = THEANO_FLAGS
os.environ['KERAS_BACKEND'] = 'theano'

import keras
keras.backend.set_image_dim_ordering('th')
from keras.layers.convolutional import Conv2D as Conv
from keras.layers.convolutional import MaxPooling2D as Pool
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.core import Activation, Dense, Dropout, Flatten
from keras.regularizers import l2 as L2
# Out:
# Using Theano backend.
# WARNING (theano.sandbox.cuda): The cuda backend is deprecated and will be removed in the next release (v0.10).  Please switch to the gpuarray backend. You can get more information about how to switch at this URL:
#  https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29
#
# Using gpu device 0: GeForce GTX 1080 (CNMeM is enabled with initial size: 95.0% of memory, cuDNN not available)

# %%
# config for specific settings wrt the sound samples used
from config import *


def to_one_hot(targets, class_count):
    """Encode target classes in a one-hot matrix.
    """
    one_hot_enc = np.zeros((len(targets), class_count))

    for r in range(len(targets)):
        one_hot_enc[r, targets[r]] = 1

    return one_hot_enc


def extract_segment(filename):
    """Get one random segment from a recording.
    """
    spec = np.load('dataset/tmp/' + filename + '.spec.npy').astype('float32')

    offset = np.random.randint(0, np.shape(spec)[1] - SEGMENT_LENGTH + 1)
    spec = spec[:, offset:offset + SEGMENT_LENGTH]

    return np.stack([spec])


def iterrows(dataframe):
    """Iterate over a random permutation of dataframe rows.
    """
    while True:
        for row in dataframe.iloc[np.random.permutation(len(dataframe))].itertuples():
            yield row


def iterbatches(batch_size, training_dataframe):
    """Generate training batches.
    """
    itrain = iterrows(training_dataframe)

    while True:
        X, y = [], []

        for i in range(batch_size):
            row = next(itrain)
            X.append(extract_segment(row.filename))
            y.append(le.transform([row.category])[0])

        X = np.stack(X)
        y = to_one_hot(np.array(y), len(labels))

        X -= AUDIO_MEAN
        X /= AUDIO_STD

        yield X, y

# %%
# main
np.random.seed(1)

logging.basicConfig(level=logging.DEBUG)
logger = logging.getLogger(__name__)

# Load dataset
meta = pd.read_csv('dataset/meta-train-data.csv')
labels = pd.unique(meta.sort_values('category')['category'])
le = sklearn.preprocessing.LabelEncoder()
le.fit(labels)

# Generate spectrograms
logger.info('Generating spectrograms...')

if not os.path.exists('dataset/tmp/'):
    os.mkdir('dataset/tmp/')

for row in tqdm(meta.itertuples(), total=len(meta)):
    spec_file = 'dataset/tmp/' + row.filename + '.spec.npy'
    audio_file = 'dataset/audio/' + row.filename

    if os.path.exists(spec_file):
        continue

    audio = pydub.AudioSegment.from_file(audio_file).set_frame_rate(SAMPLING_RATE).set_channels(1)
    audio = (np.fromstring(audio._data, dtype="int16") + 0.5) / (0x7FFF + 0.5)

    spec = librosa.feature.melspectrogram(audio, SAMPLING_RATE, n_fft=FFT_SIZE,
                                          hop_length=CHUNK_SIZE, n_mels=MEL_BANDS)
    with warnings.catch_warnings():
        warnings.simplefilter('ignore')  # Ignore log10 zero division
        spec = librosa.core.perceptual_weighting(spec, MEL_FREQS, amin=1e-5, ref_power=1e-5,
                                                 top_db=None)

    spec = np.clip(spec, 0, 100)
    np.save(spec_file, spec.astype('float16'), allow_pickle=False)
# Out:
# INFO:__main__:Generating spectrograms...
#   0%|          | 2/525 [00:00<00:28, 18.53it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp7f8m5zcm', '-vn', '-f', 'wav', '/tmp/tmp6shkxc61'])
#   1%|          | 4/525 [00:00<00:36, 14.12it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpnqx5yid0', '-vn', '-f', 'wav', '/tmp/tmpb7b8bidg'])
#   1%|          | 6/525 [00:00<00:37, 13.67it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp1xywphfn', '-vn', '-f', 'wav', '/tmp/tmptznboa5p'])
#   2%|▏         | 11/525 [00:00<00:33, 15.52it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp_eoi8sfr', '-vn', '-f', 'wav', '/tmp/tmp06yiqjnf'])
#   4%|▍         | 20/525 [00:01<00:28, 17.46it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmplq5vnqv1', '-vn', '-f', 'wav', '/tmp/tmp0tn55z4h'])
#   5%|▌         | 28/525 [00:01<00:30, 16.19it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpq4s658v0', '-vn', '-f', 'wav', '/tmp/tmp2fgj4l5q'])
#   6%|▌         | 32/525 [00:02<00:33, 14.58it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpgd1c8h_o', '-vn', '-f', 'wav', '/tmp/tmp3238qrm2'])
# DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpagt276u7', '-vn', '-f', 'wav', '/tmp/tmpm71sgr5c'])
#   8%|▊         | 42/525 [00:02<00:30, 15.83it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpss0_01v5', '-vn', '-f', 'wav', '/tmp/tmpi2hd_ovb'])
#   8%|▊         | 44/525 [00:02<00:35, 13.71it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpilw_9a1l', '-vn', '-f', 'wav', '/tmp/tmpu9gbmex_'])
#  10%|▉         | 50/525 [00:03<00:29, 15.96it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpmnfqv0d1', '-vn', '-f', 'wav', '/tmp/tmp435pd6dd'])
#  10%|█         | 54/525 [00:03<00:31, 14.95it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpql6zvke7', '-vn', '-f', 'wav', '/tmp/tmp2krfd0bj'])
#  13%|█▎        | 69/525 [00:04<00:27, 16.50it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp_sqk5ohf', '-vn', '-f', 'wav', '/tmp/tmp4txfoz8k'])
#  14%|█▍        | 73/525 [00:04<00:30, 14.93it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpoj7l237t', '-vn', '-f', 'wav', '/tmp/tmpir7htl8i'])
#  15%|█▍        | 77/525 [00:05<00:31, 14.16it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpvx68jad8', '-vn', '-f', 'wav', '/tmp/tmp1e1f115e'])
# DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp6rln2u0j', '-vn', '-f', 'wav', '/tmp/tmpey6ry2j5'])
#  15%|█▌        | 81/525 [00:05<00:36, 12.22it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpjwgq4vb_', '-vn', '-f', 'wav', '/tmp/tmpg2_qaufn'])
#  16%|█▌        | 83/525 [00:05<00:40, 10.95it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpmdza7wza', '-vn', '-f', 'wav', '/tmp/tmp5op_c8s9'])
#  20%|██        | 105/525 [00:07<00:25, 16.60it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpt27_1uws', '-vn', '-f', 'wav', '/tmp/tmph39nxtj5'])
#  20%|██        | 107/525 [00:07<00:28, 14.57it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmphxfzvovp', '-vn', '-f', 'wav', '/tmp/tmpt2i_jukc'])
#  22%|██▏       | 115/525 [00:07<00:26, 15.61it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpzz4zc0di', '-vn', '-f', 'wav', '/tmp/tmp9t5738kb'])
#  23%|██▎       | 119/525 [00:08<00:27, 14.56it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp9fdaxgyi', '-vn', '-f', 'wav', '/tmp/tmpboig3m3_'])
#  23%|██▎       | 123/525 [00:08<00:29, 13.69it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpj_6fkrn2', '-vn', '-f', 'wav', '/tmp/tmpzdtsyqv_'])
#  24%|██▍       | 127/525 [00:08<00:28, 13.89it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpywgc2t0b', '-vn', '-f', 'wav', '/tmp/tmp68tbeehk'])
#  25%|██▍       | 131/525 [00:09<00:28, 13.96it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp332l9i6c', '-vn', '-f', 'wav', '/tmp/tmpl714f8us'])
#  25%|██▌       | 133/525 [00:09<00:29, 13.12it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp1ljgn6xq', '-vn', '-f', 'wav', '/tmp/tmp3wa4prni'])
#  26%|██▋       | 139/525 [00:09<00:26, 14.60it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpymhcm_p3', '-vn', '-f', 'wav', '/tmp/tmp43cadjhf'])
#  29%|██▉       | 154/525 [00:10<00:21, 17.05it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp_2vyxhyc', '-vn', '-f', 'wav', '/tmp/tmp06gf9plf'])
#  30%|███       | 158/525 [00:10<00:25, 14.61it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpl5r1dcxu', '-vn', '-f', 'wav', '/tmp/tmpkqfiyg1v'])
#  31%|███       | 164/525 [00:11<00:23, 15.20it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpl_mf6sb3', '-vn', '-f', 'wav', '/tmp/tmpq3g12v6d'])
#  32%|███▏      | 166/525 [00:11<00:26, 13.74it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmppoi259f7', '-vn', '-f', 'wav', '/tmp/tmpyf2bvmjp'])
# DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpq6a4lrim', '-vn', '-f', 'wav', '/tmp/tmpe_s9b2_x'])
#  32%|███▏      | 168/525 [00:11<00:28, 12.41it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp_06ibnso', '-vn', '-f', 'wav', '/tmp/tmpkn4d5i8t'])
#  32%|███▏      | 170/525 [00:11<00:28, 12.50it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpgi849l4i', '-vn', '-f', 'wav', '/tmp/tmpxy5ptfe6'])
#  34%|███▍      | 179/525 [00:12<00:21, 16.21it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp_g5jpy20', '-vn', '-f', 'wav', '/tmp/tmpccggbps6'])
#  38%|███▊      | 197/525 [00:13<00:19, 16.75it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpem0_l4ng', '-vn', '-f', 'wav', '/tmp/tmp8m7halvc'])
#  38%|███▊      | 199/525 [00:13<00:22, 14.50it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpyx2fvpz9', '-vn', '-f', 'wav', '/tmp/tmpjmg5g9u4'])
#  39%|███▉      | 205/525 [00:14<00:20, 15.40it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmphqg6fvx7', '-vn', '-f', 'wav', '/tmp/tmp5poe3z8x'])
#  40%|████      | 212/525 [00:14<00:19, 16.31it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp6famns7v', '-vn', '-f', 'wav', '/tmp/tmpkzx0l8r_'])
#  42%|████▏     | 220/525 [00:14<00:19, 15.71it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp1gvk4sfv', '-vn', '-f', 'wav', '/tmp/tmpplu95vpu'])
#  43%|████▎     | 226/525 [00:15<00:20, 14.30it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpft4qncg5', '-vn', '-f', 'wav', '/tmp/tmp29w_efsg'])
#  44%|████▍     | 230/525 [00:15<00:21, 13.87it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpayhcyzqb', '-vn', '-f', 'wav', '/tmp/tmpluojy0gb'])
#  44%|████▍     | 232/525 [00:15<00:22, 13.00it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp0qelrr65', '-vn', '-f', 'wav', '/tmp/tmpffkgkyfk'])
#  45%|████▍     | 236/525 [00:16<00:20, 13.91it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp6zowz2ah', '-vn', '-f', 'wav', '/tmp/tmpmg_y77hi'])
#  46%|████▌     | 240/525 [00:16<00:20, 13.73it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmppdhxu5rx', '-vn', '-f', 'wav', '/tmp/tmpf6zluoan'])
#  49%|████▉     | 258/525 [00:17<00:16, 15.84it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp3xh916me', '-vn', '-f', 'wav', '/tmp/tmpb_8189pn'])
#  50%|█████     | 263/525 [00:17<00:15, 16.54it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpbeeki7y4', '-vn', '-f', 'wav', '/tmp/tmp9wz9yjvh'])
#  51%|█████     | 269/525 [00:18<00:13, 18.39it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpla1i1bhq', '-vn', '-f', 'wav', '/tmp/tmpwlmj_edp'])
#  52%|█████▏    | 272/525 [00:18<00:14, 18.01it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpy5g2nec1', '-vn', '-f', 'wav', '/tmp/tmp3rzep0tc'])
#  52%|█████▏    | 274/525 [00:18<00:14, 17.81it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpk8barwvb', '-vn', '-f', 'wav', '/tmp/tmphltgmm_e'])
#  53%|█████▎    | 279/525 [00:18<00:12, 19.32it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpjiydad4m', '-vn', '-f', 'wav', '/tmp/tmp05xz2_bi'])
#  54%|█████▍    | 286/525 [00:19<00:11, 21.19it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp9kgt_8sf', '-vn', '-f', 'wav', '/tmp/tmpc5_uvmrg'])
#  55%|█████▌    | 289/525 [00:19<00:11, 19.87it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpuzwtag0e', '-vn', '-f', 'wav', '/tmp/tmp9wqeg1sd'])
# DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpl_vcqv80', '-vn', '-f', 'wav', '/tmp/tmps95n7fx2'])
#  56%|█████▋    | 296/525 [00:19<00:13, 17.11it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp1ramh60v', '-vn', '-f', 'wav', '/tmp/tmpttnbungg'])
#  58%|█████▊    | 304/525 [00:20<00:13, 16.22it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpxcwrgzv0', '-vn', '-f', 'wav', '/tmp/tmpp26h4f_7'])
# DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmprplneqx4', '-vn', '-f', 'wav', '/tmp/tmpxqvvzgri'])
#  59%|█████▉    | 312/525 [00:20<00:14, 15.21it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpntwot5t1', '-vn', '-f', 'wav', '/tmp/tmpxw401zc9'])
# DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp78c24vt9', '-vn', '-f', 'wav', '/tmp/tmpq0brx58c'])
#  60%|██████    | 316/525 [00:21<00:15, 13.61it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp4hovrxhu', '-vn', '-f', 'wav', '/tmp/tmp7trhn2ol'])
#  61%|██████▏   | 322/525 [00:21<00:14, 14.42it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpst2y3e53', '-vn', '-f', 'wav', '/tmp/tmpkmcchtwe'])
#  62%|██████▏   | 324/525 [00:21<00:15, 13.33it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpgrjpjdvo', '-vn', '-f', 'wav', '/tmp/tmpekqb0hkj'])
#  65%|██████▍   | 339/525 [00:22<00:10, 18.28it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmput5muxb3', '-vn', '-f', 'wav', '/tmp/tmpz41dte63'])
# DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmps7s02nx3', '-vn', '-f', 'wav', '/tmp/tmpvg6g9uqq'])
#  65%|██████▍   | 341/525 [00:22<00:13, 14.08it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpmq18oj3q', '-vn', '-f', 'wav', '/tmp/tmp75xyxthb'])
#  67%|██████▋   | 351/525 [00:23<00:10, 16.02it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpqyjb5fom', '-vn', '-f', 'wav', '/tmp/tmp1kpdmova'])
#  68%|██████▊   | 357/525 [00:23<00:10, 15.52it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpjri4l4ga', '-vn', '-f', 'wav', '/tmp/tmpe9go0gx3'])
#  68%|██████▊   | 359/525 [00:24<00:11, 13.93it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp1czedw2u', '-vn', '-f', 'wav', '/tmp/tmp5snq4ivb'])
#  69%|██████▉   | 363/525 [00:24<00:11, 14.46it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpf4eoseec', '-vn', '-f', 'wav', '/tmp/tmp02t4c5gm'])
#  70%|██████▉   | 365/525 [00:24<00:11, 13.60it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp1g8xz6pz', '-vn', '-f', 'wav', '/tmp/tmp4p2l3ed6'])
#  73%|███████▎  | 384/525 [00:25<00:08, 16.22it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmphrmr0szq', '-vn', '-f', 'wav', '/tmp/tmp76tt6q90'])
#  75%|███████▍  | 392/525 [00:26<00:08, 15.57it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpxid2gzt3', '-vn', '-f', 'wav', '/tmp/tmpm2s8pbbh'])
#  76%|███████▌  | 398/525 [00:26<00:08, 14.91it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpc50k_ehv', '-vn', '-f', 'wav', '/tmp/tmpap57mj57'])
#  78%|███████▊  | 408/525 [00:27<00:07, 15.82it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpxn8lpjzp', '-vn', '-f', 'wav', '/tmp/tmpfs1wdf8_'])
#  78%|███████▊  | 412/525 [00:27<00:07, 14.87it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmppzyxg6_o', '-vn', '-f', 'wav', '/tmp/tmphkd8hrkq'])
#  81%|████████  | 424/525 [00:28<00:06, 16.03it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpxl_5rqw9', '-vn', '-f', 'wav', '/tmp/tmpaqok7l2z'])
#  81%|████████  | 426/525 [00:28<00:07, 14.13it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpqe59lvy9', '-vn', '-f', 'wav', '/tmp/tmphra4xxem'])
#  82%|████████▏ | 428/525 [00:28<00:07, 13.18it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpx3n2cma9', '-vn', '-f', 'wav', '/tmp/tmpf620rc5v'])
#  82%|████████▏ | 431/525 [00:28<00:06, 14.47it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp9v8t5kt_', '-vn', '-f', 'wav', '/tmp/tmpmohdbuvz'])
#  85%|████████▍ | 445/525 [00:29<00:03, 21.20it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpp1vjkhrs', '-vn', '-f', 'wav', '/tmp/tmpl48yxwao'])
#  85%|████████▌ | 448/525 [00:29<00:03, 19.36it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpyvv4395p', '-vn', '-f', 'wav', '/tmp/tmpmvhklzpp'])
#  86%|████████▌ | 451/525 [00:29<00:03, 19.16it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpsvtxn8ql', '-vn', '-f', 'wav', '/tmp/tmp75mjk222'])
#  86%|████████▋ | 453/525 [00:29<00:03, 18.61it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpileiydfg', '-vn', '-f', 'wav', '/tmp/tmpgy6zjsc8'])
#  87%|████████▋ | 459/525 [00:30<00:03, 20.21it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp_uxy2qws', '-vn', '-f', 'wav', '/tmp/tmph5_h6zg7'])
# DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpcchz8dxj', '-vn', '-f', 'wav', '/tmp/tmp7_anetgp'])
# DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmprdzzr7fe', '-vn', '-f', 'wav', '/tmp/tmpn0y5oudj'])
#  88%|████████▊ | 462/525 [00:30<00:03, 16.64it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp9sam7yo8', '-vn', '-f', 'wav', '/tmp/tmpw9jvg0gq'])
#  88%|████████▊ | 464/525 [00:30<00:04, 15.09it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpvqgl5sdm', '-vn', '-f', 'wav', '/tmp/tmp6lccs6z7'])
#  89%|████████▉ | 466/525 [00:30<00:04, 13.16it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpfahcswes', '-vn', '-f', 'wav', '/tmp/tmp443rlgjr'])
#  90%|████████▉ | 471/525 [00:31<00:03, 16.33it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpxw135oqd', '-vn', '-f', 'wav', '/tmp/tmpecmqy824'])
#  91%|█████████ | 476/525 [00:31<00:02, 18.25it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmphm_fysup', '-vn', '-f', 'wav', '/tmp/tmpl1v4qmua'])
#  91%|█████████ | 478/525 [00:31<00:02, 15.81it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpecprwynh', '-vn', '-f', 'wav', '/tmp/tmp0b5sjnsn'])
#  91%|█████████▏| 480/525 [00:31<00:03, 14.54it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmptr81pvd_', '-vn', '-f', 'wav', '/tmp/tmpv5qyng4v'])
#  94%|█████████▎| 492/525 [00:32<00:01, 16.56it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp6uzp9yn9', '-vn', '-f', 'wav', '/tmp/tmpy0oc7t62'])
# DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp8ww_nbf_', '-vn', '-f', 'wav', '/tmp/tmpr3ztwine'])
#  95%|█████████▍| 498/525 [00:32<00:01, 14.79it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp9d0f3vqk', '-vn', '-f', 'wav', '/tmp/tmpqtqzhlki'])
#  95%|█████████▌| 500/525 [00:33<00:01, 13.66it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmp43d08j1i', '-vn', '-f', 'wav', '/tmp/tmp9ioveqfj'])
#  98%|█████████▊| 516/525 [00:33<00:00, 18.20it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmpnep9ieqq', '-vn', '-f', 'wav', '/tmp/tmppdtw9nq4'])
#  99%|█████████▊| 518/525 [00:34<00:00, 15.24it/s]DEBUG:pydub.converter:subprocess.call(['avconv', '-y', '-i', '/tmp/tmprln4tw3u', '-vn', '-f', 'wav', '/tmp/tmpholx52r4'])
# 100%|██████████| 525/525 [00:34<00:00, 15.23it/s]

# %%
# Define model
logger.info('Constructing model...')

input_shape = 1, MEL_BANDS, SEGMENT_LENGTH

# load model if exists
modelfile = 'model.json'
modelweights = 'model.h5'

if os.path.exists(modelfile) and os.path.exists(modelweights):
    # open model form current directory
    with open(modelfile, 'r') as file:
        cfg = file.read()
        model = keras.models.model_from_json(cfg)

    model.load_weights(modelweights)
    logger.debug('Loaded exsisting Keras model with weights.')
else:
    # else create new model
    model = keras.models.Sequential()

    model.add(Conv(80, (3, 3), kernel_regularizer=L2(0.001), kernel_initializer='he_uniform',
                   input_shape=input_shape))
    model.add(LeakyReLU())
    model.add(Pool((3, 3), (3, 3)))

    model.add(Conv(160, (3, 3), kernel_regularizer=L2(0.001), kernel_initializer='he_uniform'))
    model.add(LeakyReLU())
    model.add(Pool((3, 3), (3, 3)))

    model.add(Conv(240, (3, 3), kernel_regularizer=L2(0.001), kernel_initializer='he_uniform'))
    model.add(LeakyReLU())
    model.add(Pool((3, 3), (3, 3)))

    model.add(Flatten())
    model.add(Dropout(0.5))

    model.add(Dense(len(labels), kernel_regularizer=L2(0.001), kernel_initializer='he_uniform'))
    model.add(Activation('softmax'))

    logger.debug('Created new Keras model .')

# compile model
optimizer = keras.optimizers.SGD(lr=0.001, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
# Out:
# INFO:__main__:Constructing model...
# DEBUG:__main__:Created new Keras model .

# %%
# Train model
batch_size = 300
EPOCH_MULTIPLIER = 10
epochs = 2000 // EPOCH_MULTIPLIER
epoch_size = len(meta) * EPOCH_MULTIPLIER
bpe = epoch_size // batch_size

logger.info('Training... (batch size of {} | {} batches per epoch)'.format(batch_size, bpe))

model.fit_generator(generator=iterbatches(batch_size, meta),
                    steps_per_epoch=bpe,
                    epochs=epochs)

with open('model.json', 'w') as file:
    file.write(model.to_json())

model.save_weights('model.h5')

with open('model_labels.json', 'w') as file:
    json.dump(le.classes_.tolist(), file)
# Out:
# INFO:__main__:Training... (batch size of 300 | 17 batches per epoch)
# Epoch 1/200
# 17/17 [==============================] - 11s - loss: 4.5127 - acc: 0.2318
# Epoch 2/200
# 17/17 [==============================] - 11s - loss: 3.0980 - acc: 0.3486
# Epoch 3/200
# 17/17 [==============================] - 11s - loss: 2.8527 - acc: 0.4043
# Epoch 4/200
# 17/17 [==============================] - 11s - loss: 2.7393 - acc: 0.4325
# Epoch 5/200
# 17/17 [==============================] - 11s - loss: 2.6469 - acc: 0.4614
# Epoch 6/200
# 17/17 [==============================] - 11s - loss: 2.5572 - acc: 0.4984
# Epoch 7/200
# 17/17 [==============================] - 11s - loss: 2.5017 - acc: 0.5129
# Epoch 8/200
# 17/17 [==============================] - 11s - loss: 2.4161 - acc: 0.5437
# Epoch 9/200
# 17/17 [==============================] - 11s - loss: 2.3818 - acc: 0.5527
# Epoch 10/200
# 17/17 [==============================] - 11s - loss: 2.3263 - acc: 0.5637
# Epoch 11/200
# 17/17 [==============================] - 11s - loss: 2.2860 - acc: 0.5790
# Epoch 12/200
# 17/17 [==============================] - 11s - loss: 2.2289 - acc: 0.6108
# Epoch 13/200
# 17/17 [==============================] - 11s - loss: 2.2073 - acc: 0.6073
# Epoch 14/200
# 17/17 [==============================] - 11s - loss: 2.1795 - acc: 0.6225
# Epoch 15/200
# 17/17 [==============================] - 11s - loss: 2.1259 - acc: 0.6369
# Epoch 16/200
# 17/17 [==============================] - 11s - loss: 2.1209 - acc: 0.6410
# Epoch 17/200
# 17/17 [==============================] - 11s - loss: 2.0869 - acc: 0.6453
# Epoch 18/200
# 17/17 [==============================] - 11s - loss: 2.0472 - acc: 0.6645
# Epoch 19/200
# 17/17 [==============================] - 11s - loss: 2.0409 - acc: 0.6576
# Epoch 20/200
# 17/17 [==============================] - 11s - loss: 2.0345 - acc: 0.6618
# Epoch 21/200
# 17/17 [==============================] - 11s - loss: 1.9789 - acc: 0.6755
# Epoch 22/200
# 17/17 [==============================] - 11s - loss: 1.9761 - acc: 0.6802
# Epoch 23/200
# 17/17 [==============================] - 11s - loss: 1.9646 - acc: 0.6833
# Epoch 24/200
# 17/17 [==============================] - 11s - loss: 1.9171 - acc: 0.6984
# Epoch 25/200
# 17/17 [==============================] - 11s - loss: 1.9297 - acc: 0.6969
# Epoch 26/200
# 17/17 [==============================] - 11s - loss: 1.8976 - acc: 0.7039
# Epoch 27/200
# 17/17 [==============================] - 11s - loss: 1.8773 - acc: 0.7108
# Epoch 28/200
# 17/17 [==============================] - 11s - loss: 1.8632 - acc: 0.7182
# Epoch 29/200
# 17/17 [==============================] - 11s - loss: 1.8428 - acc: 0.7222
# Epoch 30/200
