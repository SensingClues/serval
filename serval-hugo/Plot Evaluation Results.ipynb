# %%
import pandas as pd

df = pd.read_csv('eval-serval003-k10-amsterdam-21.csv', sep=";")
#df
df.sort_values(by=['aps'], ascending=False)

dff = df.query('aps > 0.1')
dff = dff.sort_values(by=['aps'], ascending=False)

dff
# Out:
#                               label       aps
# 20                              Dog  0.896110
# 5                  Gunshot, gunfire  0.874488
# 10                Emergency vehicle  0.857149
# 0               Boat, Water vehicle  0.807509
# 19           Train wheels squealing  0.806302
# 2                          Aircraft  0.721509
# 22                             Howl  0.700997
# 13  Fire engine, fire truck (siren)  0.674722
# 3                             Tools  0.650372
# 15                         Chainsaw  0.644155
# 21                             Bark  0.557771
# 18     Accelerating, revving, vroom  0.541049
# 11               Police car (siren)  0.540174
# 12                Ambulance (siren)  0.512799
# 14                       Motorcycle  0.456287
# 4                        Jackhammer  0.426711
# 17                           Idling  0.389828
# 7   Vehicle horn, car horn, honking  0.367495
# 9                               Bus  0.347983
# 8                    Car passing by  0.302183
# 1              Motor vehicle (road)  0.235511
# 16                  Engine starting  0.174564

# %%
dff.head(10)
# Out:
#                               label       aps
# 20                              Dog  0.896110
# 5                  Gunshot, gunfire  0.874488
# 10                Emergency vehicle  0.857149
# 0               Boat, Water vehicle  0.807509
# 19           Train wheels squealing  0.806302
# 2                          Aircraft  0.721509
# 22                             Howl  0.700997
# 13  Fire engine, fire truck (siren)  0.674722
# 3                             Tools  0.650372
# 15                         Chainsaw  0.644155

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
 


plt.rcParams["figure.figsize"] = (10,10)
 
plt.barh(y=dff.label, width=dff.aps, align='center', alpha=0.5 )

#plt.yticks(y_pos, objects)
plt.xlabel('Precision')
plt.title('Sound class Precision')

 
plt.show()

# %%
import matplotlib as mpl
print(mpl.__version__)
# Out:
# 2.2.2
