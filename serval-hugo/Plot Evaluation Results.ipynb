# %%
# read evaluation csv average presicion

import csv

with open('eval-001-k20.csv') as csvfile:
    df = csv.reader(csvfile, delimiter=';')
    
df

# %%
import pandas as pd

df = pd.read_csv('eval-001-k20.csv', sep=";")
#df
df.sort_values(by=['aps'], ascending=False)

dff = df.query('aps > 0.4')
dff = dff.sort_values(by=['aps'], ascending=False)

dff
# Out:
#                                     label       aps
# 210                              Bagpipes  0.826869
# 137                                 Music  0.786214
# 209                             Accordion  0.687724
# 0                                  Speech  0.661984
# 211                            Didgeridoo  0.655399
# 12                             Battle cry  0.652395
# 185                      Brass instrument  0.644773
# 397                   Civil defense siren  0.641536
# 207          Change ringing (campanology)  0.634627
# 396                                 Siren  0.630272
# 147                                 Banjo  0.610114
# 160                           Harpsichord  0.603878
# 208                             Harmonica  0.597206
# 15                             Whispering  0.583678
# 195  Wind instrument, woodwind instrument  0.574348
# 322                     Emergency vehicle  0.571644
# 328                        Rail transport  0.565361
# ...

# %%
dff.head()
# Out:
#           label       aps
# 210    Bagpipes  0.826869
# 137       Music  0.786214
# 209   Accordion  0.687724
# 0        Speech  0.661984
# 211  Didgeridoo  0.655399

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
 
# objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
# y_pos = np.arange(len(objects))
# performance = [10,8,6,4,2,1]

 
plt.barh(y=dff.label, width=dff.aps, align='center', alpha=0.5)
#plt.yticks(y_pos, objects)
plt.xlabel('Usage')
plt.title('Programming language usage')
 
plt.show()
