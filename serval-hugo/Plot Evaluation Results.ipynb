# %%
import pandas as pd

df = pd.read_csv('eval-serval001-k10.csv', sep=";")
#df
df.sort_values(by=['aps'], ascending=False)

dff = df.query('aps > 0.1')
dff = dff.sort_values(by=['aps'], ascending=False)

dff
# Out:
#                          label       aps
# 12                       Music  0.948365
# 0                       Speech  0.865810
# 17              Rail transport  0.698866
# 14                     Vehicle  0.617787
# 18                    Aircraft  0.507216
# 15         Boat, Water vehicle  0.481741
# 28                   Fusillade  0.458136
# 8                       Animal  0.456830
# 9       Domestic animals, pets  0.408667
# 13          Musical instrument  0.393938
# 24                     Sanding  0.364610
# 26            Gunshot, gunfire  0.328788
# 27                 Machine gun  0.320298
# 7           Speech synthesizer  0.269965
# 3   Child speech, kid speaking  0.259353
# 21                  Jackhammer  0.238620
# 30                     Cap gun  0.226422
# 19                       Tools  0.184077
# 22                      Sawing  0.163848
# 5         Narration, monologue  0.162329
# 25                  Power tool  0.132392
# 4                 Conversation  0.106387
# 6                     Babbling  0.100876

# %%
dff.head(10)
# Out:
#                      label       aps
# 12                   Music  0.948365
# 0                   Speech  0.865810
# 17          Rail transport  0.698866
# 14                 Vehicle  0.617787
# 18                Aircraft  0.507216
# 15     Boat, Water vehicle  0.481741
# 28               Fusillade  0.458136
# 8                   Animal  0.456830
# 9   Domestic animals, pets  0.408667
# 13      Musical instrument  0.393938

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
 
# objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
# y_pos = np.arange(len(objects))
# performance = [10,8,6,4,2,1]

 
plt.barh(y=dff.label, width=dff.aps, align='center', alpha=0.5)
#plt.yticks(y_pos, objects)
plt.xlabel('Usage')
plt.title('Programming language usage')
 
plt.show()
